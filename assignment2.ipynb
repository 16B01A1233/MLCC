# %%
import pandas as pd

df2008 = pd.read_csv("2008.csv")
df2018 = pd.read_csv("2018.csv")

# %%
df2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
# Model                   2404 non-null object
# Displ                   2404 non-null float64
# Cyl                     2205 non-null object
# Trans                   2205 non-null object
# Drive                   2311 non-null object
# Fuel                    2404 non-null object
# Sales Area              2404 non-null object
# Stnd                    2404 non-null object
# Underhood ID            2404 non-null object
# Veh Class               2404 non-null object
# Air Pollution Score     2404 non-null object
# FE Calc Appr            2205 non-null object
# City MPG                2205 non-null object
# Hwy MPG                 2205 non-null object
# Cmb MPG                 2205 non-null object
# Unadj Cmb MPG           2205 non-null float64
# Greenhouse Gas Score    2205 non-null object
# SmartWay                2404 non-null object
# dtypes: float64(2), object(16)
# ...

# %%
df2008.isnull().sum()
# Out:
# Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales Area                0
# Stnd                      0
# Underhood ID              0
# Veh Class                 0
# Air Pollution Score       0
# FE Calc Appr            199
# City MPG                199
# Hwy MPG                 199
# Cmb MPG                 199
# Unadj Cmb MPG           199
# Greenhouse Gas Score    199
# SmartWay                  0
# dtype: int64

# %%
df2008[df2008.isnull().any(axis=1)].shape
# Out:
# (199, 18)

# %%
sum(df2008.duplicated())
# Out:
# 25

# %%
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2682 entries, 0 to 2681
# Data columns (total 18 columns):
# Model                   2682 non-null object
# Displ                   2637 non-null float64
# Cyl                     2637 non-null float64
# Trans                   2682 non-null object
# Drive                   2682 non-null object
# Fuel                    2682 non-null object
# Cert Region             2682 non-null object
# Stnd                    2682 non-null object
# Stnd Description        2682 non-null object
# Underhood ID            2682 non-null object
# Veh Class               2682 non-null object
# Air Pollution Score     2682 non-null int64
# City MPG                2682 non-null object
# Hwy MPG                 2682 non-null object
# Cmb MPG                 2682 non-null object
# Greenhouse Gas Score    2682 non-null int64
# SmartWay                2682 non-null object
# Comb CO2                2682 non-null object
# ...

# %%
sum(df2018.duplicated())
# Out:
# 0

# %%
df2018[df2018.isnull().any(axis=1)].shape
# Out:
# (45, 18)

# %%
df2008['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df2018['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Electricity',
#        'Ethanol/Gas', 'Hydrogen'], dtype=object)

# %%
df2008.drop(columns = ['Stnd','Underhood ID','FE Calc Appr','Unadj Cmb MPG'])
# Out:
#                          Model  Displ       Cyl    Trans Drive      Fuel  \
# 0                    ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 1                    ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 2                    ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 3                    ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 4                     ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 5                     ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 6                     ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 7                     ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 8                     ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# 9                     ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 10                    ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 11                    ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# ...

# %%
df2018.drop(columns = ['Stnd','Stnd Description','Underhood ID','Comb CO2'])
# Out:
#                      Model  Displ  Cyl        Trans Drive  \
# 0                ACURA ILX    2.4  4.0        AMS-8   2WD
# 1                ACURA ILX    2.4  4.0        AMS-8   2WD
# 2                ACURA MDX    3.0  6.0        AMS-7   4WD
# 3                ACURA MDX    3.0  6.0        AMS-7   4WD
# 4                ACURA MDX    3.5  6.0   SemiAuto-9   2WD
# 5                ACURA MDX    3.5  6.0   SemiAuto-9   2WD
# 6                ACURA MDX    3.5  6.0   SemiAuto-9   2WD
# 7                ACURA MDX    3.5  6.0   SemiAuto-9   2WD
# 8                ACURA MDX    3.5  6.0   SemiAuto-9   4WD
# 9                ACURA MDX    3.5  6.0   SemiAuto-9   4WD
# 10               ACURA MDX    3.5  6.0   SemiAuto-9   4WD
# 11               ACURA MDX    3.5  6.0   SemiAuto-9   4WD
# 12               ACURA NSX    3.5  6.0        AMS-9   4WD
# 13               ACURA NSX    3.5  6.0        AMS-9   4WD
# 14               ACURA RDX    3.5  6.0   SemiAuto-6   2WD
# ...

# %%
df2008.rename(index=str, columns={"Sales Area": "Cert Region"})
# Out:
#                          Model  Displ       Cyl    Trans Drive      Fuel  \
# 0                    ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 1                    ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 2                    ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 3                    ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 4                     ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 5                     ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 6                     ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 7                     ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 8                     ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# 9                     ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 10                    ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 11                    ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# ...

# %%
new_labels = []
for col in df2008.columns:
        new_labels.append(col.lower())

# %%
for col in df2008.columns:
    print(col)
# Out:
# Model
# Displ
# Cyl
# Trans
# Drive
# Fuel
# Sales Area
# Stnd
# Underhood ID
# Veh Class
# Air Pollution Score
# FE Calc Appr
# City MPG
# Hwy MPG
# Cmb MPG
# Unadj Cmb MPG
# Greenhouse Gas Score
# SmartWay

# %%
df2008.columns = new_labels

# %%
print(new_labels)
# Out:
# ['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'sales area', 'stnd', 'underhood id', 'veh class', 'air pollution score', 'fe calc appr', 'city mpg', 'hwy mpg', 'cmb mpg', 'unadj cmb mpg', 'greenhouse gas score', 'smartway']

# %%
df2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
# model                   2404 non-null object
# displ                   2404 non-null float64
# cyl                     2205 non-null object
# trans                   2205 non-null object
# drive                   2311 non-null object
# fuel                    2404 non-null object
# sales area              2404 non-null object
# stnd                    2404 non-null object
# underhood id            2404 non-null object
# veh class               2404 non-null object
# air pollution score     2404 non-null object
# fe calc appr            2205 non-null object
# city mpg                2205 non-null object
# hwy mpg                 2205 non-null object
# cmb mpg                 2205 non-null object
# unadj cmb mpg           2205 non-null float64
# greenhouse gas score    2205 non-null object
# smartway                2404 non-null object
# dtypes: float64(2), object(16)
# ...

# %%
new_labels = []
changed_labels = []
for col in df2008.columns:
    for i in range(len(col)):
        #print(i)
        if col[i] == ' ':
            #print(col[0:i])
            new_labels.append(col[0:i])
            new_labels.append('_')
            new_labels.append(col[i+1:])
            #print(col[i+1:])

# %%
print(new_labels)
# Out:
# ['sales', '_', 'area', 'underhood', '_', 'id', 'veh', '_', 'class', 'air', '_', 'pollution score', 'air pollution', '_', 'score', 'fe', '_', 'calc appr', 'fe calc', '_', 'appr', 'city', '_', 'mpg', 'hwy', '_', 'mpg', 'cmb', '_', 'mpg', 'unadj', '_', 'cmb mpg', 'unadj cmb', '_', 'mpg', 'greenhouse', '_', 'gas score', 'greenhouse gas', '_', 'score']
